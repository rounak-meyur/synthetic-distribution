# %%
import gurobipy as grb
import networkx as nx
import numpy as np

# Function Definitions
def mycallback(model, where):
    if where == grb.GRB.Callback.MIP:
        # General MIP callback
        objbst = model.cbGet(grb.GRB.Callback.MIP_OBJBST)
        objbnd = model.cbGet(grb.GRB.Callback.MIP_OBJBND)
        time = model.cbGet(grb.GRB.Callback.RUNTIME)
        if(time>300 and abs(objbst - objbnd) < 0.005 * (1.0 + abs(objbst))):
            print('Stop early - 0.50% gap achieved time exceeds 5 minutes')
            model.terminate()
        elif(time>60 and abs(objbst - objbnd) < 0.0025 * (1.0 + abs(objbst))):
            print('Stop early - 0.25% gap achieved time exceeds 1 minute')
            model.terminate()
        elif(time>1200 and abs(objbst - objbnd) < 0.01 * (1.0 + abs(objbst))):
            print('Stop early - 1.00% gap achieved time exceeds 20 minutes')
            model.terminate()
        elif(time>1800 and abs(objbst - objbnd) < 0.05 * (1.0 + abs(objbst))):
            print('Stop early - 5.00% gap achieved time exceeds 30 minutes')
            model.terminate()
        elif(time>2400 and abs(objbst - objbnd) < 0.1 * (1.0 + abs(objbst))):
            print('Stop early - 10.0% gap achieved time exceeds 40 minutes')
            model.terminate()
    return


# Class Definitions
class MILP_secondary:
    """
    """
    def __init__(self,graph,roots,hops):
        """
        """
        self.edges = list(graph.edges())
        self.nodes = list(graph.nodes())
        print("Number of edges:",len(self.edges))
        self.hindex = [i for i,node in enumerate(self.nodes) if node not in roots]
        self.tindex = [i for i,node in enumerate(self.nodes) if node in roots]
        self.A = nx.incidence_matrix(graph,nodelist=self.nodes,
                                     edgelist=self.edges,oriented=True)
        self.I = nx.incidence_matrix(graph,nodelist=self.nodes,
                                     edgelist=self.edges,oriented=False)
        COST = nx.get_edge_attributes(graph,name='cost')
        LENGTH = nx.get_edge_attributes(graph,name='length')
        LOAD = nx.get_node_attributes(graph,name='load')
        self.c = np.array([1e-3*COST[e] for e in self.edges])
        self.l = np.array([1e-3*LENGTH[e] for e in self.edges])
        self.p = np.array([1e-3*LOAD[self.nodes[i]] for i in self.hindex])
        self.model = grb.Model(name="Get Spiders")
        self.model.ModelSense = grb.GRB.MINIMIZE
        self.__variables()
        self.__radiality()
        self.__heuristic()
        self.__powerflow()
        self.__objective()
        self.model.write("secondary.lp")
        self.optimal_edges = self.__solve()
        return
    
    def __variables(self):
        """
        Create variable initialization for MILP such that x is binary, f is a 
        continuous variable.
        """
        self.x = self.model.addMVar(len(self.edges),
                                    vtype=grb.GRB.BINARY,name='x')
        self.f = self.model.addMVar(len(self.edges),
                                    vtype=grb.GRB.CONTINUOUS,
                                    lb=-grb.GRB.INFINITY,name='f')
        self.z = self.model.addMVar(len(self.edges),
                                    vtype=grb.GRB.CONTINUOUS,
                                    lb=-grb.GRB.INFINITY,name='z')
        self.v = self.model.addMVar(len(self.nodes),
                                    vtype=grb.GRB.CONTINUOUS,
                                    lb=0.95,ub=1.00,name='v')
        self.model.update()
        return
    
    def __radiality(self):
        """
        Radiality constraints in the form of linear problem are defined:
            1. Number of edges of a forest is number of nodes except root
            2. Each connected component of forest should have a transformer
        """
        print("Setting up radiality constraints")
        self.model.addConstr(self.x.sum() == len(self.hindex), name="radiality")
        self.model.update()
        return
    
    def __heuristic(self,M=10):
        """
        """
        self.model.addConstr(
            self.A[self.hindex,:]@self.z == -np.ones(shape=(len(self.hindex),)),
            name = 'connectivity')
        self.model.addConstr(self.z - M*self.x <= 0,name="hop_a")
        self.model.addConstr(self.z + M*self.x >= 0,name="hop_b")
        self.model.addConstr(
            self.I[self.hindex,:]@self.x <= 2*np.ones(shape=(len(self.hindex),)),
            name = 'degree')
        self.model.update()
        return
    
    def __powerflow(self,r=0.81508/57.6,M=25):
        """
        """
        print("Setting up power flow constraints")
        self.model.addConstr(self.A[self.hindex,:]@self.f == -self.p,name='balance')
        self.model.addConstr(self.f - M*self.x <= 0,name="flow_a")
        self.model.addConstr(self.f + M*self.x >= 0,name="flow_b")
        expr = r*np.diag(self.l)@self.f
        self.model.addConstr(self.A.T@self.v - expr - 0.1*(1-self.x) <= 0,name='va')
        self.model.addConstr(self.A.T@self.v - expr + 0.1*(1-self.x) >= 0,name='vb')
        for i in self.tindex:
            self.model.addConstr(self.v[i]==1,name="voltage")
        self.model.update()
        return
    
    def __objective(self):
        """
        """
        self.model.setObjective(self.c @ self.x)
        self.model.update()
        return
    
    def __solve(self):
        """
        """
        # Turn off display and heuristics
        grb.setParam('OutputFlag', 1)
        grb.setParam('Heuristics', 0)
        
        # Open log file
        logfile = open('gurobi.log', 'w')
        
        # Pass data into my callback function
        self.model._lastiter = -grb.GRB.INFINITY
        self.model._lastnode = -grb.GRB.INFINITY
        self.model._logfile = logfile
        self.model._vars = self.model.getVars()
        
        # Solve model and capture solution information
        self.model.optimize(mycallback)
        
        # Close log file
        logfile.close()
        print('')
        print('Optimization complete')
        if self.model.SolCount == 0:
            print('No solution found, optimization status = %d' % self.model.Status)
            sys.exit(0)
        else:
            print('Solution found, objective = %g' % self.model.ObjVal)
            x_optimal = self.x.getAttr("x").tolist()
            return [e for i,e in enumerate(self.edges) if x_optimal[i]>0.5]

# %%
# Import necessary modules
from geographiclib.geodesic import Geodesic
from shapely.geometry import LineString,MultiPoint
from scipy.spatial import Delaunay
from itertools import combinations


# Function definition
def MeasureDistance(pt1,pt2):
    '''
    Measures the geodesic distance between two coordinates. The format of each point 
    is (longitude,latitude).
    pt1: (longitude,latitude) of point 1
    pt2: (longitude,latitude) of point 2
    '''
    lon1,lat1 = pt1
    lon2,lat2 = pt2
    geod = Geodesic.WGS84
    return geod.Inverse(lat1, lon1, lat2, lon2)['s12']

def InvertMap(input_dict):
    """
    Inverts a given mapping. The input/output mapping is provided through a dictionary.
    input_dict: input mapping
    output_dict: output mapping
    """
    output_dict = {}
    for key in input_dict:
        if input_dict[key] in list(output_dict.keys()):
            output_dict[input_dict[key]].append(key)
        else:
            output_dict[input_dict[key]]=[key]
    return output_dict



# Class definition for geometry shapes
class Link(LineString):
    """
    Derived class from Shapely LineString to compute metric distance based on 
    geographical coordinates over geometric coordinates.
    """
    def __init__(self,line_geom):
        """
        Initialize class object through inheritence
        """
        super().__init__(line_geom)
        self.geod_length = self.__length()
        return
    
    
    def __length(self):
        '''
        Computes the geographical length in meters between the ends of the link.
        '''
        if self.geom_type != 'LineString':
            print("Cannot compute length!!!")
            return None
        # Compute great circle distance
        lon1,lon2 = self.xy[0]
        lat1,lat2 = self.xy[1]
        geod = Geodesic.WGS84
        return geod.Inverse(lat1, lon1, lat2, lon2)['s12']
    
    
    def InterpolatePoints(self,min_sep=50):
        """
        Interpolate multiple points in between the line segment
        """
        points = []
        length = self.geod_length
        sep = max(min_sep,(length/15))
        for i in np.arange(0,length,sep):
            x,y = self.interpolate(i/length,normalized=True).xy
            xy = (x[0],y[0])
            points.append(xy)
        return {i:[pt.x,pt.y] for i,pt in enumerate(MultiPoint(points))}

class Spider:
    """
    Contains methods and attributes to generate the secondary distribution network
    originating from a link. The link consists of multiple transformers and uses 
    multiple engineering and economic heuristics to generate the network.
    """
    def __init__(self,homes,roads,home_to_link):
        """
        Initializes the class object with all home nodes, road network and the mapping
        between them.
        
        Input:  homes: named tuple with all residential building data
                roads: named tuple with all road network information
                home_to_link: mapping between homes and road links
        """
        self.home_load = homes.average
        self.home_cord = homes.cord
        self.road_cord = roads.cord
        self.link_to_home = InvertMap(home_to_link)
        return
    
    
    def __separate_side(self,link):
        """
        Evaluates the groups of homes on either side of the link. This would help in 
        creating network with minimum crossover of distribution lines over the road
        network.
        
        Input: link: the road link of interest
        Output: side: dictionary of homes as keys and value as 1 or -1 depending on
                which side of the link it is present.
        """
        homelist = self.link_to_home[link] if link in self.link_to_home\
            else self.link_to_home[(link[1],link[0])]
        points = [self.home_cord[h] for h in homelist]
        (x1,y1) = self.road_cord[link[0]]
        (x2,y2) = self.road_cord[link[1]]
        eqn = [((x-x1)*(y2-y1))-((y-y1)*(x2-x1)) for (x,y) in points]
        side = {home: 1 if eqn[index]>=0 else -1 for index,home in enumerate(homelist)}
        return side
    
    
    def __complete_graph_from_list(self,L):
        """
        Computes the full graph of the nodes in list L. There would be L(L-1)/2 edges 
        in the network. This is used as base network when the number of nodes mapped 
        to the link is small.
        
        Input: L: list of nodes mapped to the link of interest
        Output: graph: the full graph which would be used as base network for the 
                optimization problem.
        """
        G = nx.Graph()
        edges = combinations(L,2)
        G.add_edges_from(edges)
        return G
    
    def __delaunay_graph_from_list(self,L):
        """
        Computes the Delaunay graph of the nodes in list L. L edges in the network 
        based on the definition of Delaunay triangulation. This is used as base 
        network when the number of nodes mapped to the link is small.
        
        Input: L: list of nodes mapped to the link of interest
        Output: graph: the Delaunay graph which would be used as base network for the 
                optimization problem.
        """
        points = np.array([[self.home_cord[h][0],
                            self.home_cord[h][1]] for h in L])
        triangles = Delaunay(points).simplices
        edgelist = []
        for t in triangles:
            edges = [(L[t[0]],L[t[1]]),(L[t[1]],L[t[2]]),(L[t[2]],L[t[0]])]
            edgelist.extend(edges)
        G = nx.Graph()
        G.add_edges_from(edgelist)
        return G
    
    
    def create_dummy_graph(self,link,minsep,penalty):
        """
        Creates the base network to carry out the optimization problem. The base graph
        may be a Delaunay graph or a full graph depending on the size of the problem.
        
        Inputs: link: road link of interest for which the problem is solved.
                minsep: minimum separation in meters between the transformers.
                penalty: penalty factor for crossing the link.
        Outputs:graph: the generated base graph also called the dummy graph
                transformers: list of points along link which are probable locations 
                of transformers.
        """
        sides = self.__separate_side(link)
        home_pts = self.link_to_home[link]
        node_pos = {h:self.home_cord[h] for h in home_pts}
        load = {h:self.home_load[h]/1000.0 for h in home_pts}
                
        # Update the attributes of nodes
        link_line = Link(LineString([tuple(self.road_cord[n]) for n in link]))
        transformers = link_line.InterpolatePoints(minsep)
        node_pos.update(transformers)
        sides.update({t:0 for t in transformers})
        load.update({t:1.0 for t in transformers})
        
        # Create the base graph
        if len(home_pts)>10:
            graph = self.__delaunay_graph_from_list(home_pts)
        else:
            graph = self.__complete_graph_from_list(home_pts)
        new_edges = [(t,n) for t in transformers for n in home_pts]
        graph.add_edges_from(new_edges)
        nx.set_node_attributes(graph,node_pos,'cord')
        nx.set_node_attributes(graph,load,'load')
        edge_cost = {e:MeasureDistance(node_pos[e[0]],node_pos[e[1]])*\
                     (1+penalty*abs(sides[e[0]]-sides[e[1]])) \
                      for e in list(graph.edges())}
        edge_length = {e:MeasureDistance(node_pos[e[0]],node_pos[e[1]])\
                      for e in list(graph.edges())}
        nx.set_edge_attributes(graph,edge_length,'length')
        nx.set_edge_attributes(graph,edge_cost,'cost')
        return graph,transformers
    
    def get_nodes(self,link,minsep):
        """
        Gets all the nodes from the dummy graph created before solving the optimization 
        problem.
        
        Inputs: link: road link of interest for which the problem is solved.
                minsep: minimum separation in meters between the transformers.
        Outputs:home_pts: list of residential points
                transformers: list of points along link which are probable locations 
                of transformers.
        """
        home_pts = self.link_to_home[link]
        if len(home_pts) > 100:
            link_line = Link(LineString([tuple(self.road_cord[n]) for n in link]))
            transformers = link_line.InterpolatePoints(minsep)
        else:
            link_line = Link(LineString([tuple(self.road_cord[n]) for n in link]))
            transformers = link_line.InterpolatePoints(minsep)
        return home_pts,transformers
    
    def generate_optimal_topology(self,link,minsep=50,penalty=0.5,hops=4):
        """
        Calls the MILP problem and solves it using gurobi solver.
        
        Inputs: link: road link of interest for which the problem is solved.
                minsep: minimum separation in meters between the transformers.
                penalty: penalty factor for crossing the link.
        Outputs:forest: the generated forest graph which is the secondary network
                roots: list of points along link which are actual locations of 
                transformers.
        """
        graph,roots = self.create_dummy_graph(link,minsep,penalty)
        edgelist = MILP_secondary(graph,roots,hops).optimal_edges
        forest = nx.Graph()
        forest.add_edges_from(edgelist)
        node_cord = {node: roots[node] if node in roots\
                     else self.home_cord[node]\
                     for node in list(forest.nodes())}
        nx.set_node_attributes(forest,node_cord,'cord')
        node_load = {node:sum([self.home_load[h] for h in list(nx.descendants(forest,node))]) \
                     if node in roots else self.home_load[node] for node in list(forest.nodes())}
        nx.set_node_attributes(forest,node_load,'load')
        return forest,roots

# %%
# Import necessary modules
import sys,os
import pandas as pd
import matplotlib.pyplot as plt

# Define paths to required directories
workPath = os.getcwd()
inpPath = workPath + "/input/"
libPath = workPath + "/Libraries/"
csvPath = workPath + "/csv/"
figPath = workPath + "/figs/"

sys.path.append(libPath)
from pyExtractDatalib import Query

# Extract data from directories
q_object = Query(csvPath)
gdf_home,homes = q_object.GetHomes()
roads = q_object.GetRoads()

df_hmap = pd.read_csv(csvPath+'home2link.csv')
H2Link = dict([(t.HID, (t.source, t.target)) for t in df_hmap.itertuples()])
spider_obj = Spider(homes,roads,H2Link)
L2Home = spider_obj.link_to_home

# %%
from IPython import display
# %matplotlib inline
from matplotlib.lines import Line2D

link = (171528302, 171526182)
fig = plt.figure(figsize=(15,36))

for i,sep in enumerate([200,250,300,350,400,450]):
    forest,roots = spider_obj.generate_optimal_topology(link,minsep=sep)
    pos_nodes = nx.get_node_attributes(forest,'cord')
    
    # Display the problem
    H,T = spider_obj.get_nodes(link,minsep=sep)
    points = np.array([[homes.cord[h][0],homes.cord[h][1]] for h in H])
    ax1 = fig.add_subplot(6,2,2*i+1)
    nx.draw_networkx_edges(roads.graph,pos=roads.cord,edgelist=[link],ax=ax1,
                            width=2.5,edge_color='k')
    ax1.scatter([homes.cord[h][0] for h in H],[homes.cord[h][1] for h in H],c='r',
                s=25.0,marker='*')
    ax1.scatter([t[0] for t in list(T.values())],[t[1] for t in list(T.values())],
                c='b',s=50.0,marker='*')
    ax1.grid(b=True)
    ax1.set_xlabel("Longitude",fontsize=15)
    ax1.set_ylabel("Latitude",fontsize=15)
    ax1.set_title("Minimum separation between transformers: "+str(sep)+" meters",fontsize=12)
    leglines = [Line2D([0], [0], color='black', markerfacecolor='blue', marker='*',markersize=10),
                Line2D([0], [0], color='white', markerfacecolor='blue', marker='*',markersize=10),
                Line2D([0], [0], color='white', markerfacecolor='red', marker='*',markersize=10)]
    ax1.legend(leglines,['road link','probable local transformers',
                        'individual residential consumers'],
              loc='best',ncol=1,prop={'size': 10})

    # Display the secondary network
    ax2 = fig.add_subplot(6,2,2*i+2)
    ax2.grid(b=True)
    nx.draw_networkx_edges(roads.graph,pos=roads.cord,edgelist=[link],ax=ax2,
                           edge_color='k',width=1.5)
    nodelist = list(forest.nodes())
    colors = ['red' if n not in roots else 'blue' for n in nodelist]
    nx.draw_networkx(forest,pos=pos_nodes,edgelist=list(forest.edges()),
                     ax=ax2,edge_color='crimson',width=1,with_labels=False,
                     node_size=20.0,node_shape='*',node_color=colors)

    ax2.tick_params(left=True,bottom=True,labelleft=True,labelbottom=True)
    ax2.set_xlabel("Longitude",fontsize=15)
    ax2.set_ylabel("Latitude",fontsize=15)
    ax2.set_title("Generated synthetic network",fontsize=12)


    leglines = [Line2D([0], [0], color='black', markerfacecolor='blue', marker='*',markersize=10),
                Line2D([0], [0], color='crimson', markerfacecolor='crimson', marker='*',markersize=10),
                Line2D([0], [0], color='white', markerfacecolor='blue', marker='*',markersize=10),
                Line2D([0], [0], color='white', markerfacecolor='red', marker='*',markersize=10)]
    ax2.legend(leglines,['road link','secondary network','local transformers','residences'],
              loc='best',ncol=1,prop={'size': 10})
    ax2.autoscale(tight=True)

fig.savefig("{}{}.png".format(workPath,"output_step2_ensemble1"))
# Out:
# Number of edges: 387
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2398 and linear constraint 2399 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2411 rows, 1199 columns and 7939 nonzeros
# Model fingerprint: 0x78b3f73b
# Variable types: 812 continuous, 387 integer (387 binary)
# Coefficient statistics:
#   Matrix range     [7e-05, 3e+01]
#   Objective range  [7e-03, 4e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 338 rows and 13 columns
# Presolve time: 0.01s
# Presolved: 2073 rows, 1186 columns, 6301 nonzeros
# Variable types: 799 continuous, 387 integer (387 binary)
#
# Root relaxation: objective 2.401236e+00, 983 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.40124    0   21          -    2.40124      -     -    0s
#      0     0    2.77679    0   18          -    2.77679      -     -    0s
#      0     0    3.00681    0   16          -    3.00681      -     -    0s
#      0     0    3.21899    0   20          -    3.21899      -     -    0s
#      0     0    3.24855    0    5          -    3.24855      -     -    0s
# H    0     0                       6.3274452    3.24855  48.7%     -    0s
#      0     0    3.32536    0    5    6.32745    3.32536  47.4%     -    0s
#      0     0    3.32548    0    4    6.32745    3.32548  47.4%     -    0s
# *    0     0               0       3.3271782    3.32718  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 3
#   MIR: 12
#
# Explored 1 nodes (1759 simplex iterations) in 0.17 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 3.32718 6.32745
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.327178186473e+00, best bound 3.327178186473e+00, gap 0.0000%
#
# User-callback calls 128, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 3.32718
# Number of edges: 337
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2098 and linear constraint 2099 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2109 rows, 1047 columns and 6937 nonzeros
# Model fingerprint: 0x7f794774
# Variable types: 710 continuous, 337 integer (337 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [1e-02, 4e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 286 rows and 11 columns
# Presolve time: 0.01s
# Presolved: 1823 rows, 1036 columns, 5551 nonzeros
# Variable types: 699 continuous, 337 integer (337 binary)
#
# Root relaxation: objective 2.223688e+00, 892 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.22369    0   21          -    2.22369      -     -    0s
#      0     0    2.62453    0   18          -    2.62453      -     -    0s
#      0     0    2.86325    0   19          -    2.86325      -     -    0s
#      0     0    3.16502    0   18          -    3.16502      -     -    0s
#      0     0    3.21198    0   12          -    3.21198      -     -    0s
#      0     0    3.22960    0   11          -    3.22960      -     -    0s
#      0     0    3.23004    0   23          -    3.23004      -     -    0s
#      0     0    3.23012    0   12          -    3.23012      -     -    0s
#      0     0    3.23314    0   13          -    3.23314      -     -    0s
#      0     0    3.23550    0   13          -    3.23550      -     -    0s
#      0     0    3.23578    0   10          -    3.23578      -     -    0s
#      0     0    3.23578    0   10          -    3.23578      -     -    0s
#      0     0    3.23578    0   10          -    3.23578      -     -    0s
#      0     2    3.23578    0   10          -    3.23578      -     -    0s
# *  138   155              22       6.4292002    3.30879  48.5%  38.6    0s
# *  161   178              30       5.9659110    3.30879  44.5%  35.7    0s
# *  236   249              16       3.5670979    3.30887  7.24%  33.5    0s
# *  284   255              16       3.3261151    3.30931  0.51%  33.6    0s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 5
#   MIR: 16
#
# Explored 411 nodes (12002 simplex iterations) in 0.28 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 3.32612 3.5671 5.96591 6.4292
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.326115058324e+00, best bound 3.326115058324e+00, gap 0.0000%
#
# User-callback calls 1015, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 3.32612
# Number of edges: 287
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1798 and linear constraint 1799 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1807 rows, 895 columns and 5935 nonzeros
# Model fingerprint: 0xd5885dde
# Variable types: 608 continuous, 287 integer (287 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 4e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 234 rows and 9 columns
# Presolve time: 0.01s
# Presolved: 1573 rows, 886 columns, 4801 nonzeros
# Variable types: 599 continuous, 287 integer (287 binary)
#
# Root relaxation: objective 2.593151e+00, 835 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.59315    0   21          -    2.59315      -     -    0s
#      0     0    2.97902    0   17          -    2.97902      -     -    0s
#      0     0    3.17591    0   18          -    3.17591      -     -    0s
#      0     0    3.48943    0    8          -    3.48943      -     -    0s
#      0     0    3.51911    0    8          -    3.51911      -     -    0s
# H    0     0                       6.4258365    3.51911  45.2%     -    0s
#      0     0    3.51943    0    8    6.42584    3.51943  45.2%     -    0s
# H    0     0                       3.5384870    3.51943  0.54%     -    0s
# H    0     0                       3.5234009    3.51943  0.11%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 5
#   MIR: 16
#
# Explored 1 nodes (1172 simplex iterations) in 0.09 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 3.5234 3.53849 6.42584
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.523400863132e+00, best bound 3.523400863132e+00, gap 0.0000%
#
# User-callback calls 104, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 3.5234
# Number of edges: 262
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1648 and linear constraint 1649 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1656 rows, 819 columns and 5434 nonzeros
# Model fingerprint: 0x8a4d2ab0
# Variable types: 557 continuous, 262 integer (262 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 4e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 208 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 1448 rows, 811 columns, 4426 nonzeros
# Variable types: 549 continuous, 262 integer (262 binary)
#
# Root relaxation: objective 2.517223e+00, 726 iterations, 0.01 seconds
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.51722    0   12          -    2.51722      -     -    0s
#      0     0    2.81822    0   12          -    2.81822      -     -    0s
#      0     0    2.95035    0   15          -    2.95035      -     -    0s
#      0     0    3.26902    0   20          -    3.26902      -     -    0s
#      0     0    3.26902    0   16          -    3.26902      -     -    0s
#      0     0    3.26902    0   16          -    3.26902      -     -    0s
#      0     0    3.26902    0   17          -    3.26902      -     -    0s
#      0     0    3.26902    0   19          -    3.26902      -     -    0s
#      0     0    3.26902    0   20          -    3.26902      -     -    0s
#      0     0    3.26902    0   20          -    3.26902      -     -    0s
# H    0     0                       9.8351148    3.26902  66.8%     -    0s
#      0     0    3.26902    0   20    9.83511    3.26902  66.8%     -    0s
#      0     0    3.26902    0   20    9.83511    3.26902  66.8%     -    0s
#      0     2    3.26902    0   20    9.83511    3.26902  66.8%     -    0s
# *  105   124              15       3.6866482    3.36939  8.61%  27.7    0s
# *  163   147              23       3.6748084    3.38121  7.99%  24.7    0s
# *  211   152              19       3.6677273    3.38121  7.81%  23.7    0s
# *  212   152              19       3.6521554    3.38121  7.42%  23.6    0s
# *  256   147              16       3.6410365    3.38121  7.14%  22.5    0s
# *  264   147              15       3.6326184    3.38121  6.92%  22.2    0s
# *  314   162              13       3.6248259    3.40353  6.10%  21.1    0s
# *  326   162              20       3.6026949    3.40353  5.53%  21.0    0s
# *  328   162              18       3.5987276    3.40353  5.42%  21.1    0s
# *  329   162              17       3.5876087    3.40353  5.13%  21.1    0s
# *  378   185              14       3.4591666    3.41466  1.29%  20.5    0s
# *  443   118              13       3.4480478    3.42857  0.56%  19.3    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 7
#   MIR: 16
#   Zero half: 2
#
# Explored 499 nodes (10232 simplex iterations) in 0.23 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 3.44805 3.45917 3.58761 ... 3.66773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.448047757487e+00, best bound 3.448047757487e+00, gap 0.0000%
#
# User-callback calls 1188, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 3.44805
# Number of edges: 237
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1498 and linear constraint 1499 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1505 rows, 743 columns and 4933 nonzeros
# Model fingerprint: 0x687170d5
# Variable types: 506 continuous, 237 integer (237 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 4e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 182 rows and 7 columns
# Presolve time: 0.01s
# Presolved: 1323 rows, 736 columns, 4051 nonzeros
# Variable types: 499 continuous, 237 integer (237 binary)
#
# Root relaxation: objective 3.083223e+00, 733 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.08322    0   15          -    3.08322      -     -    0s
#      0     0    3.25611    0   14          -    3.25611      -     -    0s
#      0     0    3.42559    0   18          -    3.42559      -     -    0s
#      0     0    3.57604    0   24          -    3.57604      -     -    0s
#      0     0    3.59272    0   28          -    3.59272      -     -    0s
#      0     0    3.59915    0   29          -    3.59915      -     -    0s
#      0     0    3.61075    0   29          -    3.61075      -     -    0s
#      0     0    3.61075    0   29          -    3.61075      -     -    0s
# H    0     0                       8.6767112    3.61075  58.4%     -    0s
# H    0     0                       8.6655923    3.61075  58.3%     -    0s
#      0     0    3.61936    0   25    8.66559    3.61936  58.2%     -    0s
#      0     0    3.62004    0   29    8.66559    3.62004  58.2%     -    0s
#      0     0    3.62265    0   26    8.66559    3.62265  58.2%     -    0s
#      0     0    3.62265    0   26    8.66559    3.62265  58.2%     -    0s
#      0     0    3.62265    0   26    8.66559    3.62265  58.2%     -    0s
#      0     2    3.62265    0   26    8.66559    3.62265  58.2%     -    0s
# *  120   122              13       3.9580742    3.71770  6.07%  40.5    0s
# *  192   131              16       3.9131787    3.79884  2.92%  31.8    0s
# *  282   117              15       3.9050358    3.80509  2.56%  26.1    0s
# *  410    91              15       3.8980239    3.83451  1.63%  21.9    0s
# *  414    91              13       3.8869050    3.83451  1.35%  21.9    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 6
#   MIR: 19
#   Flow cover: 1
#   Zero half: 2
#
# Explored 499 nodes (10408 simplex iterations) in 0.21 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 3.88691 3.89802 3.90504 ... 8.67671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.886905040223e+00, best bound 3.886905040223e+00, gap 0.0000%
#
# User-callback calls 1175, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 3.88691
# Number of edges: 212
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1348 and linear constraint 1349 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1354 rows, 667 columns and 4432 nonzeros
# Model fingerprint: 0xb0e74f51
# Variable types: 455 continuous, 212 integer (212 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 4e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 156 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1198 rows, 661 columns, 3676 nonzeros
# Variable types: 449 continuous, 212 integer (212 binary)
#
# Root relaxation: objective 3.394888e+00, 707 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.39489    0   15          -    3.39489      -     -    0s
#      0     0    3.56675    0   10          -    3.56675      -     -    0s
#      0     0    3.67433    0   11          -    3.67433      -     -    0s
#      0     0    3.78377    0   17          -    3.78377      -     -    0s
#      0     0    3.79470    0   13          -    3.79470      -     -    0s
#      0     0    3.81383    0   19          -    3.81383      -     -    0s
#      0     0    3.81642    0   19          -    3.81642      -     -    0s
#      0     0    3.83195    0   20          -    3.83195      -     -    0s
#      0     0    3.83470    0   19          -    3.83470      -     -    0s
# H    0     0                       6.3689969    3.83470  39.8%     -    0s
#      0     0    3.84025    0   21    6.36900    3.84025  39.7%     -    0s
#      0     0    3.84252    0   21    6.36900    3.84252  39.7%     -    0s
#      0     0    3.85189    0   20    6.36900    3.85189  39.5%     -    0s
#      0     0    3.85189    0   20    6.36900    3.85189  39.5%     -    0s
#      0     0    3.85189    0   20    6.36900    3.85189  39.5%     -    0s
#      0     0    3.85189    0   20    6.36900    3.85189  39.5%     -    0s
#      0     2    3.85189    0   20    6.36900    3.85189  39.5%     -    0s
# *  105   117              16       4.2051424    3.88546  7.60%  43.5    0s
# *  121   117              14       4.1618810    3.88546  6.64%  43.0    0s
# *  220   133              11       4.1617466    3.90166  6.25%  30.1    0s
# *  234   133              14       4.1006005    3.90166  4.85%  29.1    0s
# *  275   143              13       4.0966332    3.92219  4.26%  26.8    0s
# *  276   143              12       4.0855143    3.92219  4.00%  26.8    0s
# *  308   153              14       4.0786355    3.92276  3.82%  25.4    0s
# *  385   164              14       4.0656086    3.93340  3.25%  23.1    0s
# *  386   164              13       4.0616414    3.93340  3.16%  23.1    0s
# *  387   164              12       4.0505225    3.93340  2.89%  23.0    0s
# *  509   157              12       4.0323917    3.95926  1.81%  20.2    0s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 5
#   MIR: 29
#   Flow cover: 1
#   Inf proof: 1
#   Zero half: 1
#
# Explored 843 nodes (14041 simplex iterations) in 0.25 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 4.03239 4.05052 4.06164 ... 4.16188
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.032391744393e+00, best bound 4.032391744393e+00, gap 0.0000%
#
# User-callback calls 1879, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 4.03239

# %%
fig = plt.figure(figsize=(20,30))

for i,sep in enumerate([200,250,300,350,400,450]):
    # Display the problem
    H,T = spider_obj.get_nodes(link,minsep=sep)
    points = np.array([[homes.cord[h][0],homes.cord[h][1]] for h in H])
    ax1 = fig.add_subplot(6,4,4*i+1)
    nx.draw_networkx_edges(roads.graph,pos=roads.cord,edgelist=[link],ax=ax1,
                            width=2.5,edge_color='k')
    ax1.scatter([homes.cord[h][0] for h in H],[homes.cord[h][1] for h in H],c='r',
                s=25.0,marker='*')
    ax1.scatter([t[0] for t in list(T.values())],[t[1] for t in list(T.values())],
                c='b',s=50.0,marker='*')
    ax1.grid(b=True)
    ax1.set_xlabel("Longitude",fontsize=10)
    ax1.set_ylabel("Latitude",fontsize=10)
    ax1.set_title("Minimum transformer separation: "+str(sep)+" meters",fontsize=10)
    leglines = [Line2D([0], [0], color='black', markerfacecolor='blue', marker='*',markersize=10),
                Line2D([0], [0], color='white', markerfacecolor='blue', marker='*',markersize=10),
                Line2D([0], [0], color='white', markerfacecolor='red', marker='*',markersize=10)]
    ax1.legend(leglines,['road link','probable local transformers',
                        'individual residential consumers'],
              loc='best',ncol=1,prop={'size': 8})
    for j,pen in enumerate([0.1,1,10]):
        forest,roots = spider_obj.generate_optimal_topology(link,minsep=sep,penalty=pen)
        pos_nodes = nx.get_node_attributes(forest,'cord')

        # Display the secondary network
        ax2 = fig.add_subplot(6,4,4*i+j+2)
        ax2.grid(b=True)
        nx.draw_networkx_edges(roads.graph,pos=roads.cord,edgelist=[link],ax=ax2,
                               edge_color='k',width=1.5)
        nodelist = list(forest.nodes())
        colors = ['red' if n not in roots else 'blue' for n in nodelist]
        nx.draw_networkx(forest,pos=pos_nodes,edgelist=list(forest.edges()),
                         ax=ax2,edge_color='crimson',width=1,with_labels=False,
                         node_size=20.0,node_shape='*',node_color=colors)

        ax2.tick_params(left=True,bottom=True,labelleft=True,labelbottom=True)
        ax2.set_xlabel("Longitude",fontsize=10)
        ax2.set_ylabel("Latitude",fontsize=10)
        ax2.set_title("Generated network with penalty:"+str(pen),fontsize=10)


        leglines = [Line2D([0], [0], color='black', markerfacecolor='blue', marker='*',markersize=10),
                    Line2D([0], [0], color='crimson', markerfacecolor='crimson', marker='*',markersize=10),
                    Line2D([0], [0], color='white', markerfacecolor='blue', marker='*',markersize=10),
                    Line2D([0], [0], color='white', markerfacecolor='red', marker='*',markersize=10)]
        ax2.legend(leglines,['road link','secondary network','local transformers','residences'],
                  loc='best',ncol=1,prop={'size': 8})
        ax2.autoscale(tight=True)

fig.savefig("{}{}.png".format(workPath,"output_step2_ensemble2"))
# Out:
# Number of edges: 387
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2398 and linear constraint 2399 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2411 rows, 1199 columns and 7939 nonzeros
# Model fingerprint: 0xe9677094
# Variable types: 812 continuous, 387 integer (387 binary)
# Coefficient statistics:
#   Matrix range     [7e-05, 3e+01]
#   Objective range  [5e-03, 3e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 338 rows and 13 columns
# Presolve time: 0.02s
# Presolved: 2073 rows, 1186 columns, 6301 nonzeros
# Variable types: 799 continuous, 387 integer (387 binary)
#
# Root relaxation: objective 1.935111e+00, 1102 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.93511    0   21          -    1.93511      -     -    0s
#      0     0    2.46187    0   12          -    2.46187      -     -    0s
#      0     0    2.52600    0   16          -    2.52600      -     -    0s
#      0     0    2.62072    0   15          -    2.62072      -     -    0s
#      0     0    2.62346    0   20          -    2.62346      -     -    0s
#      0     0    2.62567    0   13          -    2.62567      -     -    0s
#      0     0    2.69645    0   14          -    2.69645      -     -    0s
#      0     0    2.69651    0   13          -    2.69651      -     -    0s
#      0     0    2.70364    0   18          -    2.70364      -     -    0s
#      0     0    2.70410    0   19          -    2.70410      -     -    0s
#      0     0    2.71121    0   18          -    2.71121      -     -    0s
#      0     0    2.71122    0   18          -    2.71122      -     -    0s
#      0     0    2.71122    0   18          -    2.71122      -     -    0s
#      0     2    2.71122    0   18          -    2.71122      -     -    0s
# *   30    30               5       3.6107935    2.78591  22.8%  33.9    0s
# *   34    37               7       3.4441260    2.78591  19.1%  36.0    0s
# *   43    35               7       2.9462804    2.78591  5.44%  32.1    0s
# *   72    11               7       2.8645878    2.80373  2.12%  23.7    0s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 4
#   MIR: 24
#   Flow cover: 1
#
# Explored 96 nodes (3641 simplex iterations) in 0.34 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 2.86459 2.94628 3.44413 3.61079
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.864587783475e+00, best bound 2.864587783475e+00, gap 0.0000%
#
# User-callback calls 396, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 2.86459
# Number of edges: 387
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2398 and linear constraint 2399 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2411 rows, 1199 columns and 7939 nonzeros
# Model fingerprint: 0x7a6aca39
# Variable types: 812 continuous, 387 integer (387 binary)
# Coefficient statistics:
#   Matrix range     [7e-05, 3e+01]
#   Objective range  [1e-02, 5e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 338 rows and 13 columns
# Presolve time: 0.01s
# Presolved: 2073 rows, 1186 columns, 6301 nonzeros
# Variable types: 799 continuous, 387 integer (387 binary)
#
# Root relaxation: objective 2.850129e+00, 960 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.85013    0   14          -    2.85013      -     -    0s
#      0     0    3.13698    0   20          -    3.13698      -     -    0s
#      0     0    3.34373    0   13          -    3.34373      -     -    0s
#      0     0    3.46165    0   23          -    3.46165      -     -    0s
#      0     0    3.46436    0   23          -    3.46436      -     -    0s
#      0     0    3.47046    0   23          -    3.47046      -     -    0s
#      0     0    3.50389    0   24          -    3.50389      -     -    0s
#      0     0    3.50421    0   24          -    3.50421      -     -    0s
#      0     0    3.50556    0   26          -    3.50556      -     -    0s
#      0     0    3.50645    0   26          -    3.50645      -     -    0s
#      0     0    3.50645    0   26          -    3.50645      -     -    0s
#      0     2    3.50645    0   26          -    3.50645      -     -    0s
# *   89   102              13       3.9483702    3.55935  9.85%  40.2    0s
# *  136   103              10       3.7142432    3.69909  0.41%  29.6    0s
# *  164    67               9       3.7102759    3.69916  0.30%  26.2    0s
# *  165    67               8       3.6991570    3.69916  0.00%  26.0    0s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 5
#   MIR: 11
#
# Explored 193 nodes (6089 simplex iterations) in 0.36 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 3.69916 3.71028 3.71424 3.94837
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.699157009655e+00, best bound 3.699157009655e+00, gap 0.0000%
#
# User-callback calls 576, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 3.69916
# Number of edges: 387
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2398 and linear constraint 2399 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2411 rows, 1199 columns and 7939 nonzeros
# Model fingerprint: 0xbe003965
# Variable types: 812 continuous, 387 integer (387 binary)
# Coefficient statistics:
#   Matrix range     [7e-05, 3e+01]
#   Objective range  [1e-02, 3e+01]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 338 rows and 13 columns
# Presolve time: 0.01s
# Presolved: 2073 rows, 1186 columns, 6301 nonzeros
# Variable types: 799 continuous, 387 integer (387 binary)
#
# Root relaxation: objective 4.766008e+00, 971 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.76601    0   15          -    4.76601      -     -    0s
#      0     0    4.98052    0   16          -    4.98052      -     -    0s
#      0     0    5.21695    0   13          -    5.21695      -     -    0s
#      0     0    5.37783    0   18          -    5.37783      -     -    0s
#      0     0    5.38129    0   18          -    5.38129      -     -    0s
# H    0     0                       5.5861968    5.38129  3.67%     -    0s
#      0     0    5.41736    0   18    5.58620    5.41736  3.02%     -    0s
#      0     0    5.41736    0   12    5.58620    5.41736  3.02%     -    0s
#      0     0    5.41736    0   16    5.58620    5.41736  3.02%     -    0s
#      0     0    5.41736    0   17    5.58620    5.41736  3.02%     -    0s
#      0     0    5.41736    0   17    5.58620    5.41736  3.02%     -    0s
#      0     0    5.41736    0   21    5.58620    5.41736  3.02%     -    0s
#      0     0    5.41736    0   21    5.58620    5.41736  3.02%     -    0s
# H    0     0                       5.5293889    5.41736  2.03%     -    0s
#      0     0    5.45525    0   12    5.52939    5.45525  1.34%     -    0s
#      0     0    5.46461    0   19    5.52939    5.46461  1.17%     -    0s
#      0     0    5.46522    0   21    5.52939    5.46522  1.16%     -    0s
#      0     0    5.46522    0   21    5.52939    5.46522  1.16%     -    0s
#      0     0    5.46864    0   21    5.52939    5.46864  1.10%     -    0s
#      0     0    5.47146    0   21    5.52939    5.47146  1.05%     -    0s
#      0     0    5.47858    0   19    5.52939    5.47858  0.92%     -    0s
#      0     0    5.48256    0   21    5.52939    5.48256  0.85%     -    0s
#      0     0    5.49025    0   21    5.52939    5.49025  0.71%     -    0s
#      0     0    5.49245    0   21    5.52939    5.49245  0.67%     -    0s
#      0     0    5.49912    0   21    5.52939    5.49912  0.55%     -    0s
#      0     0    5.50039    0    8    5.52939    5.50039  0.52%     -    0s
#      0     0    5.50039    0    8    5.52939    5.50039  0.52%     -    0s
#      0     0    5.50039    0    8    5.52939    5.50039  0.52%     -    0s
#      0     0    5.50039    0   12    5.52939    5.50039  0.52%     -    0s
#      0     0    5.50039    0   13    5.52939    5.50039  0.52%     -    0s
#      0     0    5.50039    0    8    5.52939    5.50039  0.52%     -    0s
# H    0     0                       5.5143028    5.50039  0.25%     -    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 1
#   Implied bound: 1
#   MIR: 10
#   Zero half: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (2301 simplex iterations) in 0.26 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 5.5143 5.52939 5.5862
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.514302806277e+00, best bound 5.514302806277e+00, gap 0.0000%
#
# User-callback calls 240, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 5.5143
# Number of edges: 337
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2098 and linear constraint 2099 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2109 rows, 1047 columns and 6937 nonzeros
# Model fingerprint: 0x3851fffa
# Variable types: 710 continuous, 337 integer (337 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [8e-03, 3e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 286 rows and 11 columns
# Presolve time: 0.01s
# Presolved: 1823 rows, 1036 columns, 5551 nonzeros
# Variable types: 699 continuous, 337 integer (337 binary)
#
# Root relaxation: objective 1.808456e+00, 959 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.80846    0   21          -    1.80846      -     -    0s
#      0     0    2.32434    0   21          -    2.32434      -     -    0s
#      0     0    2.47658    0   22          -    2.47658      -     -    0s
#      0     0    2.62948    0   21          -    2.62948      -     -    0s
#      0     0    2.70299    0   15          -    2.70299      -     -    0s
#      0     0    2.79588    0   20          -    2.79588      -     -    0s
#      0     0    2.80014    0   12          -    2.80014      -     -    0s
#      0     0    2.80101    0   15          -    2.80101      -     -    0s
#      0     0    2.80206    0   15          -    2.80206      -     -    0s
#      0     0    2.80207    0   15          -    2.80207      -     -    0s
#      0     0    2.80214    0   15          -    2.80214      -     -    0s
# H    0     0                      10.2279893    2.80214  72.6%     -    0s
# H    0     0                       9.6808510    2.80214  71.1%     -    0s
#      0     0    2.80285    0   14    9.68085    2.80285  71.0%     -    0s
#      0     0    2.80285    0   14    9.68085    2.80285  71.0%     -    0s
#      0     2    2.80285    0   14    9.68085    2.80285  71.0%     -    0s
# *   95   102              13       3.0090395    2.82556  6.10%  40.3    0s
# *  181   107              10       2.9586342    2.83607  4.14%  26.8    0s
# *  196   102              21       2.8838172    2.83607  1.66%  25.6    0s
# *  347     1              21       2.8779545    2.86873  0.32%  17.1    0s
# *  358     1              20       2.8740927    2.87409  0.00%  16.8    0s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 4
#   MIR: 59
#   Zero half: 1
#
# Explored 374 nodes (7702 simplex iterations) in 0.38 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 2.87409 2.87795 2.88382 ... 10.228
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.874092740826e+00, best bound 2.874092740826e+00, gap 0.0000%
#
# User-callback calls 958, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 2.87409
# Number of edges: 337
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2098 and linear constraint 2099 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2109 rows, 1047 columns and 6937 nonzeros
# Model fingerprint: 0x84caf0f6
# Variable types: 710 continuous, 337 integer (337 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [1e-02, 5e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 286 rows and 11 columns
# Presolve time: 0.01s
# Presolved: 1823 rows, 1036 columns, 5551 nonzeros
# Variable types: 699 continuous, 337 integer (337 binary)
#
# Root relaxation: objective 2.627652e+00, 974 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.62765    0   18          -    2.62765      -     -    0s
#      0     0    3.10028    0   15          -    3.10028      -     -    0s
#      0     0    3.22042    0   24          -    3.22042      -     -    0s
#      0     0    3.35879    0   14          -    3.35879      -     -    0s
#      0     0    3.38242    0   16          -    3.38242      -     -    0s
#      0     0    3.39383    0   17          -    3.39383      -     -    0s
#      0     0    3.39548    0   14          -    3.39548      -     -    0s
#      0     0    3.39595    0   14          -    3.39595      -     -    0s
#      0     0    3.40933    0   15          -    3.40933      -     -    0s
#      0     0    3.41540    0   16          -    3.41540      -     -    0s
# H    0     0                       4.3257046    3.41540  21.0%     -    0s
#      0     0    3.47867    0   15    4.32570    3.47867  19.6%     -    0s
#      0     0    3.47867    0   18    4.32570    3.47867  19.6%     -    0s
#      0     0    3.47867    0   21    4.32570    3.47867  19.6%     -    0s
#      0     0    3.47867    0   16    4.32570    3.47867  19.6%     -    0s
#      0     0    3.50971    0   24    4.32570    3.50971  18.9%     -    0s
#      0     0    3.54785    0   11    4.32570    3.54785  18.0%     -    0s
# H    0     0                       4.1969390    3.54785  15.5%     -    0s
# H    0     0                       3.9906393    3.54785  11.1%     -    0s
#      0     0    3.59327    0   10    3.99064    3.59327  10.0%     -    0s
#      0     0    3.59327    0   18    3.99064    3.59327  10.0%     -    0s
#      0     0    3.59327    0   21    3.99064    3.59327  10.0%     -    0s
#      0     0    3.59327    0   20    3.99064    3.59327  10.0%     -    0s
#      0     0    3.59327    0   10    3.99064    3.59327  10.0%     -    0s
#      0     0    3.59327    0   10    3.99064    3.59327  10.0%     -    0s
#      0     0    3.60069    0   12    3.99064    3.60069  9.77%     -    0s
#      0     0    3.60263    0   17    3.99064    3.60263  9.72%     -    0s
# H    0     0                       3.7756903    3.60263  4.58%     -    0s
# H    0     0                       3.6258696    3.60263  0.64%     -    0s
# H    0     0                       3.6219023    3.61078  0.31%     -    0s
#      0     0    3.61078    0   17    3.62190    3.61078  0.31%     -    0s
#      0     0    3.61078    0   10    3.62190    3.61078  0.31%     -    0s
# H    0     0                       3.6107834    3.61078  0.00%     -    0s
#      0     0    3.61078    0    2    3.61078    3.61078  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 6
#   GUB cover: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (3603 simplex iterations) in 0.43 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 3.61078 3.6219 3.62587 ... 4.3257
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.610783411212e+00, best bound 3.610783411212e+00, gap 0.0000%
#
# User-callback calls 300, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 3.61078
# Number of edges: 337
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 2098 and linear constraint 2099 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 2109 rows, 1047 columns and 6937 nonzeros
# Model fingerprint: 0x1cf1e704
# Variable types: 710 continuous, 337 integer (337 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [1e-02, 3e+01]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 286 rows and 11 columns
# Presolve time: 0.01s
# Presolved: 1823 rows, 1036 columns, 5551 nonzeros
# Variable types: 699 continuous, 337 integer (337 binary)
#
# Root relaxation: objective 4.359816e+00, 945 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.35982    0   19          -    4.35982      -     -    0s
#      0     0    4.76292    0   15          -    4.76292      -     -    0s
#      0     0    4.76431    0   21          -    4.76431      -     -    0s
#      0     0    4.99813    0   19          -    4.99813      -     -    0s
#      0     0    5.00637    0   15          -    5.00637      -     -    0s
#      0     0    5.00797    0   15          -    5.00797      -     -    0s
#      0     0    5.00815    0   17          -    5.00815      -     -    0s
# H    0     0                       5.1047178    5.00815  1.89%     -    0s
# H    0     0                       5.0896316    5.00815  1.60%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   MIR: 7
#   Zero half: 2
#
# Explored 1 nodes (1238 simplex iterations) in 0.13 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 5.08963 5.10472
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.089631610122e+00, best bound 5.089631610122e+00, gap 0.0000%
#
# User-callback calls 118, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 5.08963
# Number of edges: 287
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1798 and linear constraint 1799 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1807 rows, 895 columns and 5935 nonzeros
# Model fingerprint: 0xda0368db
# Variable types: 608 continuous, 287 integer (287 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 234 rows and 9 columns
# Presolve time: 0.01s
# Presolved: 1573 rows, 886 columns, 4801 nonzeros
# Variable types: 599 continuous, 287 integer (287 binary)
#
# Root relaxation: objective 2.089863e+00, 850 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.08986    0   20          -    2.08986      -     -    0s
#      0     0    2.54583    0   10          -    2.54583      -     -    0s
#      0     0    2.70414    0   20          -    2.70414      -     -    0s
#      0     0    2.83579    0   22          -    2.83579      -     -    0s
#      0     0    2.88252    0   13          -    2.88252      -     -    0s
#      0     0    2.96635    0   11          -    2.96635      -     -    0s
#      0     0    2.96647    0   11          -    2.96647      -     -    0s
# H    0     0                       9.2739753    2.96647  68.0%     -    0s
# H    0     0                       8.6144015    2.96647  65.6%     -    0s
#      0     0    2.96647    0   11    8.61440    2.96647  65.6%     -    0s
#      0     2    2.96647    0   11    8.61440    2.96647  65.6%     -    0s
# *  105   124              14       3.0420861    2.99968  1.39%  33.8    0s
# *  164   105              12       3.0309672    3.00524  0.85%  25.1    0s
# *  196    74              16       3.0308524    3.00524  0.85%  21.9    0s
# *  203    74              17       3.0238405    3.00524  0.62%  21.4    0s
# *  207    74              15       3.0127216    3.00524  0.25%  21.1    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 5
#   MIR: 28
#   Flow cover: 2
#   Zero half: 1
#
# Explored 283 nodes (5878 simplex iterations) in 0.20 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 3.01272 3.02384 3.03085 ... 9.27398
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.012721619856e+00, best bound 3.012721619856e+00, gap 0.0000%
#
# User-callback calls 719, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 3.01272
# Number of edges: 287
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1798 and linear constraint 1799 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1807 rows, 895 columns and 5935 nonzeros
# Model fingerprint: 0xe73163f9
# Variable types: 608 continuous, 287 integer (287 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 5e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 234 rows and 9 columns
# Presolve time: 0.01s
# Presolved: 1573 rows, 886 columns, 4801 nonzeros
# Variable types: 599 continuous, 287 integer (287 binary)
#
# Root relaxation: objective 3.110908e+00, 930 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.11091    0   20          -    3.11091      -     -    0s
#      0     0    3.42142    0   18          -    3.42142      -     -    0s
#      0     0    3.54882    0   18          -    3.54882      -     -    0s
#      0     0    3.69406    0   14          -    3.69406      -     -    0s
#      0     0    3.69633    0   11          -    3.69633      -     -    0s
#      0     0    3.69633    0   17          -    3.69633      -     -    0s
#      0     0    3.69633    0   15          -    3.69633      -     -    0s
#      0     0    3.69633    0   15          -    3.69633      -     -    0s
#      0     0    3.69633    0   15          -    3.69633      -     -    0s
#      0     2    3.69633    0   15          -    3.69633      -     -    0s
# *   31    34               5       3.9741918    3.88485  2.25%  34.5    0s
# *   41    34               5       3.9525930    3.88485  1.71%  38.7    0s
# *   61    12               4       3.9414741    3.89572  1.16%  27.6    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 5
#   MIR: 19
#
# Explored 87 nodes (3216 simplex iterations) in 0.24 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 3.94147 3.95259 3.97419
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.941474112455e+00, best bound 3.941474112455e+00, gap 0.0000%
#
# User-callback calls 338, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 3.94147
# Number of edges: 287
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1798 and linear constraint 1799 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1807 rows, 895 columns and 5935 nonzeros
# Model fingerprint: 0x2bd3fc94
# Variable types: 608 continuous, 287 integer (287 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+01]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 234 rows and 9 columns
# Presolve time: 0.01s
# Presolved: 1573 rows, 886 columns, 4801 nonzeros
# Variable types: 599 continuous, 287 integer (287 binary)
#
# Root relaxation: objective 5.383637e+00, 886 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.38364    0   17          -    5.38364      -     -    0s
#      0     0    5.79111    0   19          -    5.79111      -     -    0s
#      0     0    5.80776    0   15          -    5.80776      -     -    0s
#      0     0    5.98970    0   12          -    5.98970      -     -    0s
#      0     0    6.03434    0   15          -    6.03434      -     -    0s
#      0     0    6.04549    0    7          -    6.04549      -     -    0s
#      0     0    6.05033    0   12          -    6.05033      -     -    0s
#      0     0    6.05062    0   13          -    6.05062      -     -    0s
#      0     0    6.05062    0   13          -    6.05062      -     -    0s
#      0     0    6.05062    0   13          -    6.05062      -     -    0s
#      0     2    6.05062    0   13          -    6.05062      -     -    0s
# *   57    66              10       6.2785992    6.14678  2.10%  45.0    0s
# *  101    40               6       6.2458815    6.14678  1.59%  31.3    0s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 7
#   Flow cover: 3
#   Zero half: 2
#
# Explored 146 nodes (4355 simplex iterations) in 0.27 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 6.24588 6.2786
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.245881546622e+00, best bound 6.245881546622e+00, gap 0.0000%
#
# User-callback calls 459, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 6.24588
# Number of edges: 262
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1648 and linear constraint 1649 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1656 rows, 819 columns and 5434 nonzeros
# Model fingerprint: 0x89ce86a9
# Variable types: 557 continuous, 262 integer (262 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 208 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 1448 rows, 811 columns, 4426 nonzeros
# Variable types: 549 continuous, 262 integer (262 binary)
#
# Root relaxation: objective 2.062604e+00, 781 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.06260    0   20          -    2.06260      -     -    0s
#      0     0    2.44901    0   11          -    2.44901      -     -    0s
#      0     0    2.62580    0   12          -    2.62580      -     -    0s
#      0     0    2.74721    0   18          -    2.74721      -     -    0s
#      0     0    2.74721    0   23          -    2.74721      -     -    0s
#      0     0    2.81147    0   24          -    2.81147      -     -    0s
#      0     0    2.81147    0   24          -    2.81147      -     -    0s
#      0     0    2.81147    0   15          -    2.81147      -     -    0s
# H    0     0                       8.1947096    2.81147  65.7%     -    0s
# H    0     0                       6.3229072    2.81147  55.5%     -    0s
#      0     0    2.84879    0   27    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   27    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   28    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   21    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   19    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   16    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   16    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   26    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   26    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   27    6.32291    2.84879  54.9%     -    0s
#      0     0    2.84879    0   29    6.32291    2.84879  54.9%     -    0s
# H    0     0                       6.2455794    2.84879  54.4%     -    0s
#      0     0    2.84879    0   29    6.24558    2.84879  54.4%     -    0s
#      0     0    2.87409    0   30    6.24558    2.87409  54.0%     -    0s
#      0     0    2.87409    0   27    6.24558    2.87409  54.0%     -    0s
#      0     0    2.87409    0   27    6.24558    2.87409  54.0%     -    0s
#      0     0    2.87409    0   32    6.24558    2.87409  54.0%     -    0s
#      0     0    2.87409    0   12    6.24558    2.87409  54.0%     -    0s
# H    0     0                       4.6541370    2.87409  38.2%     -    0s
# H    0     0                       3.9821224    2.87409  27.8%     -    0s
# H    0     0                       3.8890992    2.87409  26.1%     -    0s
#      0     0    2.89055    0   34    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   20    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   22    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   16    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   21    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   17    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   27    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   31    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   35    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   16    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   17    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   17    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   17    3.88910    2.89055  25.7%     -    0s
#      0     0    2.89055    0   17    3.88910    2.89055  25.7%     -    0s
#      0     2    2.89055    0   17    3.88910    2.89055  25.7%     -    0s
# *  146   151              14       3.0554774    2.92216  4.36%  28.0    0s
# *  153   151              15       3.0388817    2.92216  3.84%  28.5    0s
# *  213   137              15       2.9649582    2.93311  1.07%  23.4    0s
# *  291    92              19       2.9641881    2.93719  0.91%  19.6    0s
# *  366    55              17       2.9619671    2.94083  0.71%  17.1    0s
# *  377    55              18       2.9562626    2.94245  0.47%  16.9    0s
# *  392    55              16       2.9547530    2.94245  0.42%  16.3    0s
# *  416     0              15       2.9468275    2.94683  0.00%  15.5    0s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 4
#   MIR: 32
#   Flow cover: 1
#   Inf proof: 1
#
# Explored 472 nodes (9627 simplex iterations) in 0.73 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 2.94683 2.95475 2.95626 ... 3.98212
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.946827483225e+00, best bound 2.946827483225e+00, gap 0.0000%
#
# User-callback calls 1395, time in user-callback 0.02 sec
#
# Optimization complete
# Solution found, objective = 2.94683
# Number of edges: 262
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1648 and linear constraint 1649 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1656 rows, 819 columns and 5434 nonzeros
# Model fingerprint: 0x79bbc334
# Variable types: 557 continuous, 262 integer (262 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 5e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 208 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 1448 rows, 811 columns, 4426 nonzeros
# Variable types: 549 continuous, 262 integer (262 binary)
#
# Root relaxation: objective 2.963290e+00, 803 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.96329    0   16          -    2.96329      -     -    0s
#      0     0    3.23400    0   18          -    3.23400      -     -    0s
#      0     0    3.39557    0   20          -    3.39557      -     -    0s
#      0     0    3.60270    0   23          -    3.60270      -     -    0s
#      0     0    3.62843    0   22          -    3.62843      -     -    0s
#      0     0    3.62843    0   22          -    3.62843      -     -    0s
#      0     0    3.64130    0    8          -    3.64130      -     -    0s
# H    0     0                       9.8201490    3.64130  62.9%     -    0s
#      0     0    3.64130    0    8    9.82015    3.64130  62.9%     -    0s
#      0     2    3.64130    0    8    9.82015    3.64130  62.9%     -    0s
# *   73    84              10       4.0097892    3.73757  6.79%  34.3    0s
# *  141    94              13       3.9948004    3.84947  3.64%  25.6    0s
# *  159    79              12       3.9858445    3.84947  3.42%  24.0    0s
# *  170    79              12       3.9850759    3.84947  3.40%  23.0    0s
# *  183    79              16       3.9838484    3.84947  3.37%  22.1    0s
# *  184    79              15       3.9760559    3.84947  3.18%  22.0    0s
# *  275    68              12       3.9245714    3.86709  1.46%  19.6    0s
# *  276    68              11       3.9148469    3.86709  1.22%  19.6    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 5
#   MIR: 13
#   Flow cover: 1
#   Zero half: 2
#
# Explored 363 nodes (7059 simplex iterations) in 0.20 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 3.91485 3.92457 3.97606 ... 9.82015
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.914846905413e+00, best bound 3.914846905413e+00, gap 0.0000%
#
# User-callback calls 891, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 3.91485
# Number of edges: 262
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1648 and linear constraint 1649 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1656 rows, 819 columns and 5434 nonzeros
# Model fingerprint: 0xc0d8af84
# Variable types: 557 continuous, 262 integer (262 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+01]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 208 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 1448 rows, 811 columns, 4426 nonzeros
# Variable types: 549 continuous, 262 integer (262 binary)
#
# Root relaxation: objective 4.933442e+00, 864 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.93344    0   23          -    4.93344      -     -    0s
#      0     0    5.23632    0   20          -    5.23632      -     -    0s
#      0     0    5.40803    0   21          -    5.40803      -     -    0s
#      0     0    5.40803    0   23          -    5.40803      -     -    0s
#      0     0    5.43544    0   22          -    5.43544      -     -    0s
#      0     0    5.43544    0   22          -    5.43544      -     -    0s
# H    0     0                      14.8304561    5.43544  63.3%     -    0s
#      0     0    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   23   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   22   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
#      0     0    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
#      0     2    5.43544    0   20   14.83046    5.43544  63.3%     -    0s
# *  361   363              61       8.9338508    5.49025  38.5%  19.2    0s
# *  426   362              11       5.8037535    5.53411  4.65%  18.7    0s
# *  506   255               9       5.7357579    5.61447  2.11%  18.3    0s
# *  509   255               8       5.7317906    5.61447  2.05%  18.3    0s
# *  510   255               7       5.7206717    5.61447  1.86%  18.3    0s
#
# Cutting planes:
#   Gomory: 9
#   MIR: 22
#   Flow cover: 2
#   Inf proof: 1
#
# Explored 601 nodes (11671 simplex iterations) in 0.39 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 5.72067 5.73179 5.73576 ... 14.8305
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.720671731913e+00, best bound 5.720671731913e+00, gap 0.0000%
#
# User-callback calls 1446, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 5.72067
# Number of edges: 237
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1498 and linear constraint 1499 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1505 rows, 743 columns and 4933 nonzeros
# Model fingerprint: 0x6309d533
# Variable types: 506 continuous, 237 integer (237 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 182 rows and 7 columns
# Presolve time: 0.01s
# Presolved: 1323 rows, 736 columns, 4051 nonzeros
# Variable types: 499 continuous, 237 integer (237 binary)
#
# Root relaxation: objective 2.542209e+00, 657 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.54221    0   11          -    2.54221      -     -    0s
#      0     0    2.77725    0   15          -    2.77725      -     -    0s
#      0     0    2.90387    0   13          -    2.90387      -     -    0s
#      0     0    3.07065    0   15          -    3.07065      -     -    0s
#      0     0    3.07065    0   20          -    3.07065      -     -    0s
#      0     0    3.07065    0   22          -    3.07065      -     -    0s
#      0     0    3.08275    0   27          -    3.08275      -     -    0s
#      0     0    3.08342    0   28          -    3.08342      -     -    0s
# H    0     0                       5.3686409    3.08342  42.6%     -    0s
#      0     0    3.11327    0   27    5.36864    3.11327  42.0%     -    0s
#      0     0    3.11327    0   13    5.36864    3.11327  42.0%     -    0s
#      0     0    3.11327    0   13    5.36864    3.11327  42.0%     -    0s
# H    0     0                       5.1831043    3.11327  39.9%     -    0s
#      0     0    3.11908    0   13    5.18310    3.11908  39.8%     -    0s
#      0     2    3.11908    0   13    5.18310    3.11908  39.8%     -    0s
# *  121   124              19       3.3365705    3.13565  6.02%  34.6    0s
# *  139   119              21       3.2745388    3.14588  3.93%  31.5    0s
# *  206   116              19       3.2598133    3.14588  3.49%  25.4    0s
# *  211   116              16       3.2595056    3.14588  3.49%  25.1    0s
# *  236   100              20       3.2421817    3.14763  2.92%  23.4    0s
# *  245   100              15       3.2270956    3.16069  2.06%  23.1    0s
# *  289    47              14       3.2252766    3.18713  1.18%  21.2    0s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 6
#   MIR: 24
#   Zero half: 1
#
# Explored 343 nodes (7350 simplex iterations) in 0.21 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 3.22528 3.2271 3.24218 ... 5.36864
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.225276598568e+00, best bound 3.225276598568e+00, gap 0.0000%
#
# User-callback calls 859, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 3.22528
# Number of edges: 237
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1498 and linear constraint 1499 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1505 rows, 743 columns and 4933 nonzeros
# Model fingerprint: 0x02a27c58
# Variable types: 506 continuous, 237 integer (237 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 5e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 182 rows and 7 columns
# Presolve time: 0.01s
# Presolved: 1323 rows, 736 columns, 4051 nonzeros
# Variable types: 499 continuous, 237 integer (237 binary)
#
# Root relaxation: objective 3.666043e+00, 784 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.66604    0   14          -    3.66604      -     -    0s
#      0     0    4.04036    0   14          -    4.04036      -     -    0s
#      0     0    4.20527    0   21          -    4.20527      -     -    0s
#      0     0    4.23335    0   20          -    4.23335      -     -    0s
#      0     0    4.28527    0   16          -    4.28527      -     -    0s
# H    0     0                      11.8936131    4.28527  64.0%     -    0s
# H    0     0                      10.3325767    4.28527  58.5%     -    0s
#      0     0    4.29122    0   16   10.33258    4.29122  58.5%     -    0s
#      0     0    4.29122    0   16   10.33258    4.29122  58.5%     -    0s
#      0     0    4.29122    0   16   10.33258    4.29122  58.5%     -    0s
#      0     2    4.29122    0   16   10.33258    4.29122  58.5%     -    0s
# *   71    84              11       4.8418179    4.35487  10.1%  37.6    0s
# *  106    99              20       4.7408081    4.35487  8.14%  30.2    0s
# *  108    99               6       4.3757140    4.35487  0.48%  29.9    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 3
#   MIR: 20
#   Zero half: 3
#
# Explored 193 nodes (4912 simplex iterations) in 0.17 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 4.37571 4.74081 4.84182 ... 11.8936
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.375713982308e+00, best bound 4.375713982308e+00, gap 0.0000%
#
# User-callback calls 529, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 4.37571
# Number of edges: 237
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1498 and linear constraint 1499 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1505 rows, 743 columns and 4933 nonzeros
# Model fingerprint: 0x86062a55
# Variable types: 506 continuous, 237 integer (237 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+01]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 182 rows and 7 columns
# Presolve time: 0.01s
# Presolved: 1323 rows, 736 columns, 4051 nonzeros
# Variable types: 499 continuous, 237 integer (237 binary)
#
# Root relaxation: objective 6.490691e+00, 908 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.49069    0   22          -    6.49069      -     -    0s
#      0     0    7.12764    0   24          -    7.12764      -     -    0s
#      0     0    7.25303    0   23          -    7.25303      -     -    0s
#      0     0    7.26772    0   20          -    7.26772      -     -    0s
#      0     0    7.26772    0   20          -    7.26772      -     -    0s
#      0     0    7.56644    0   16          -    7.56644      -     -    0s
#      0     0    7.56644    0   10          -    7.56644      -     -    0s
#      0     0    7.63368    0   22          -    7.63368      -     -    0s
#      0     0    7.63535    0   24          -    7.63535      -     -    0s
#      0     0    7.64152    0   22          -    7.64152      -     -    0s
#      0     0    7.64164    0   28          -    7.64164      -     -    0s
# H    0     0                      34.4219360    7.64164  77.8%     -    0s
# H    0     0                      30.0220757    7.64164  74.5%     -    0s
#      0     0    7.64199    0   26   30.02208    7.64199  74.5%     -    0s
#      0     0    7.64218    0   27   30.02208    7.64218  74.5%     -    0s
#      0     0    7.64227    0   26   30.02208    7.64227  74.5%     -    0s
#      0     0    7.64227    0   26   30.02208    7.64227  74.5%     -    0s
#      0     2    7.64227    0   26   30.02208    7.64227  74.5%     -    0s
# *  118   126              14       8.4476260    7.70197  8.83%  42.9    0s
# *  397   121              12       8.2611763    7.92875  4.02%  24.8    0s
# *  451   106              16       8.2572091    7.97201  3.45%  23.5    0s
# *  456   106              15       8.2460902    7.97201  3.32%  23.5    0s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 2
#   MIR: 31
#   Inf proof: 2
#
# Explored 666 nodes (14048 simplex iterations) in 0.30 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 8.24609 8.25721 8.26118 ... 34.4219
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.246090204255e+00, best bound 8.246090204255e+00, gap 0.0000%
#
# User-callback calls 1539, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 8.24609
# Number of edges: 212
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1348 and linear constraint 1349 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1354 rows, 667 columns and 4432 nonzeros
# Model fingerprint: 0x2e5f52fa
# Variable types: 455 continuous, 212 integer (212 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 156 rows and 6 columns
# Presolve time: 0.01s
# Presolved: 1198 rows, 661 columns, 3676 nonzeros
# Variable types: 449 continuous, 212 integer (212 binary)
#
# Root relaxation: objective 2.786841e+00, 638 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.78684    0   16          -    2.78684      -     -    0s
#      0     0    3.03279    0    9          -    3.03279      -     -    0s
#      0     0    3.13068    0   13          -    3.13068      -     -    0s
#      0     0    3.23474    0   12          -    3.23474      -     -    0s
#      0     0    3.23617    0    8          -    3.23617      -     -    0s
#      0     0    3.25067    0    8          -    3.25067      -     -    0s
#      0     0    3.25693    0   19          -    3.25693      -     -    0s
#      0     0    3.25799    0   21          -    3.25799      -     -    0s
#      0     0    3.26001    0   12          -    3.26001      -     -    0s
#      0     0    3.26001    0   12          -    3.26001      -     -    0s
#      0     0    3.26531    0   12          -    3.26531      -     -    0s
#      0     0    3.26548    0   13          -    3.26548      -     -    0s
#      0     0    3.26570    0   15          -    3.26570      -     -    0s
# H    0     0                       7.5646601    3.26570  56.8%     -    0s
#      0     0    3.27475    0   16    7.56466    3.27475  56.7%     -    0s
#      0     0    3.28550    0   16    7.56466    3.28550  56.6%     -    0s
#      0     0    3.28659    0   15    7.56466    3.28659  56.6%     -    0s
#      0     0    3.28659    0   15    7.56466    3.28659  56.6%     -    0s
#      0     0    3.29090    0   18    7.56466    3.29090  56.5%     -    0s
#      0     0    3.29337    0   17    7.56466    3.29337  56.5%     -    0s
#      0     0    3.29337    0   17    7.56466    3.29337  56.5%     -    0s
#      0     0    3.29579    0   16    7.56466    3.29579  56.4%     -    0s
# H    0     0                       7.1955074    3.29579  54.2%     -    0s
#      0     0    3.29856    0   19    7.19551    3.29856  54.2%     -    0s
#      0     0    3.29856    0   19    7.19551    3.29856  54.2%     -    0s
#      0     0    3.31284    0   19    7.19551    3.31284  54.0%     -    0s
#      0     0    3.31284    0   19    7.19551    3.31284  54.0%     -    0s
#      0     2    3.31284    0   19    7.19551    3.31284  54.0%     -    0s
# *  175   192              24       5.0816992    3.32271  34.6%  25.4    0s
# *  220   204               9       3.3923622    3.32502  1.99%  26.2    0s
# *  250   188               8       3.3860556    3.33542  1.50%  25.0    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 5
#   MIR: 22
#   Zero half: 2
#
# Explored 499 nodes (8466 simplex iterations) in 0.41 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 3.38606 3.39236 5.0817 ... 7.56466
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.386055627348e+00, best bound 3.386055627348e+00, gap 0.0000%
#
# User-callback calls 1292, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 3.38606
# Number of edges: 212
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1348 and linear constraint 1349 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1354 rows, 667 columns and 4432 nonzeros
# Model fingerprint: 0x2befe80e
# Variable types: 455 continuous, 212 integer (212 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 5e+00]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 156 rows and 6 columns
# Presolve time: 0.01s
# Presolved: 1198 rows, 661 columns, 3676 nonzeros
# Variable types: 449 continuous, 212 integer (212 binary)
#
# Root relaxation: objective 3.992211e+00, 638 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.99221    0   20          -    3.99221      -     -    0s
#      0     0    4.32529    0   18          -    4.32529      -     -    0s
#      0     0    4.43813    0   19          -    4.43813      -     -    0s
#      0     0    4.44450    0   21          -    4.44450      -     -    0s
#      0     0    4.45585    0   21          -    4.45585      -     -    0s
#      0     0    4.46090    0   19          -    4.46090      -     -    0s
#      0     0    4.46090    0   19          -    4.46090      -     -    0s
#      0     0    4.49411    0   21          -    4.49411      -     -    0s
#      0     0    4.49554    0   16          -    4.49554      -     -    0s
#      0     0    4.49554    0   16          -    4.49554      -     -    0s
#      0     2    4.49554    0   16          -    4.49554      -     -    0s
# *   22    22               3       4.7172291    4.50511  4.50%  45.9    0s
# *   31    20               6       4.5229985    4.50511  0.40%  42.9    0s
# *   44     1               4       4.5079123    4.50791  0.00%  33.3    0s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 2
#   MIR: 16
#
# Explored 53 nodes (2577 simplex iterations) in 0.19 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 4.50791 4.523 4.71723
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.507912307570e+00, best bound 4.507912307570e+00, gap 0.0000%
#
# User-callback calls 252, time in user-callback 0.00 sec
#
# Optimization complete
# Solution found, objective = 4.50791
# Number of edges: 212
# Setting up radiality constraints
# Setting up power flow constraints
# Warning: linear constraint 1348 and linear constraint 1349 have the same name "voltage"
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Parameter Heuristics unchanged
#    Value: 0.0  Min: 0.0  Max: 1.0  Default: 0.05
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 1354 rows, 667 columns and 4432 nonzeros
# Model fingerprint: 0x2b6f5696
# Variable types: 455 continuous, 212 integer (212 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e-02, 3e+01]
#   Bounds range     [9e-01, 1e+00]
#   RHS range        [3e-04, 3e+01]
# Presolve removed 156 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1198 rows, 661 columns, 3676 nonzeros
# Variable types: 449 continuous, 212 integer (212 binary)
#
# Root relaxation: objective 6.599349e+00, 764 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.59935    0   23          -    6.59935      -     -    0s
#      0     0    7.08053    0   23          -    7.08053      -     -    0s
#      0     0    7.21135    0   23          -    7.21135      -     -    0s
#      0     0    7.29433    0   19          -    7.29433      -     -    0s
#      0     0    7.29433    0   19          -    7.29433      -     -    0s
# H    0     0                      12.5626253    7.29433  41.9%     -    0s
#      0     0    7.31322    0   20   12.56263    7.31322  41.8%     -    0s
#      0     0    7.31322    0   24   12.56263    7.31322  41.8%     -    0s
#      0     0    7.31322    0   23   12.56263    7.31322  41.8%     -    0s
#      0     0    7.31449    0   13   12.56263    7.31449  41.8%     -    0s
#      0     0    7.31449    0   13   12.56263    7.31449  41.8%     -    0s
#      0     0    7.33081    0   20   12.56263    7.33081  41.6%     -    0s
#      0     0    7.33103    0   20   12.56263    7.33103  41.6%     -    0s
#      0     0    7.33651    0   20   12.56263    7.33651  41.6%     -    0s
#      0     0    7.33677    0   21   12.56263    7.33677  41.6%     -    0s
#      0     0    7.33855    0   26   12.56263    7.33855  41.6%     -    0s
#      0     0    7.33855    0   26   12.56263    7.33855  41.6%     -    0s
#      0     2    7.33855    0   26   12.56263    7.33855  41.6%     -    0s
# *  203   197              33      12.2124053    7.51237  38.5%  17.8    0s
# *  244   195              31      11.4476329    7.51858  34.3%  17.2    0s
# *  267   195              31      11.4123550    7.51858  34.1%  16.6    0s
# *  345   254              18       9.8823091    7.55333  23.6%  16.1    0s
# *  482   300              20       9.8202272    7.55333  23.1%  17.9    0s
# *  532   332              14       8.6727962    7.59467  12.4%  18.1    0s
# *  793   312              18       8.6199506    7.90775  8.26%  17.5    0s
# *  872   312              14       8.4578084    7.92483  6.30%  17.5    0s
# *  920   243              11       8.1577459    8.01900  1.70%  17.1    0s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 2
#   MIR: 22
#   Zero half: 1
#
# Explored 1056 nodes (19217 simplex iterations) in 0.37 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 8.15775 8.45781 8.61995 ... 12.5626
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.157745860672e+00, best bound 8.157745860672e+00, gap 0.0000%
#
# User-callback calls 2343, time in user-callback 0.01 sec
#
# Optimization complete
# Solution found, objective = 8.15775
